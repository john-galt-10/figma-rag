# %%
import pandas as pd

# %%
pwd
# Out:
# 'c:\\Users\\samue\\git\\figma-rag\\notebooks'

# %%
path = r"C:\Users\samue\git\figma-rag\data\raw\figma_docs\manifest.jsonl"
df = pd.read_json(path, lines=True)
df
# Out:
#                                            document_id  \
# 0    help-center-10250387712407-transfer-a-project-...
# 1             help-center-10278790616215-pay-for-figma
# 2    help-center-10386065399319-manage-who-can-crea...
# 3    help-center-10550242467991-playground-files-fo...
# 4    help-center-11756626706199-analyze-engagement-...
# ..                                                 ...
# 798  help-center-9067379354135-add-figma-files-to-g...
# 799  help-center-9141292269847-find-and-replace-in-...
# 800  help-center-9141430250391-find-and-replace-tex...
# 801  help-center-9359912208663-run-voting-sessions-...
# 802  help-center-9771500257687-organize-your-canvas...
#
#                                                  title  \
# 0    Transfer a project or team to a different account
# 1                                        Pay for Figma
# 2      Manage who can create a team in an organization
# 3             Playground files for widgets and plugins
# ...

# %%
df.iloc[215]
# Out:
# document_id        help-center-26620239826199-layers-101-explore-...
# title                                Layers 101: Explore layer types
# source_url         https://help.figma.com/hc/en-us/articles/26620...
# source_type                                              help_center
# product_area                          layers-101-explore-layer-types
# fetch_timestamp                     2026-06-18T17:30:35.145816+00:00
# raw_file_path      C:/Users/samue/git/figma-rag/data/raw/figma_do...
# Name: 215, dtype: str

# %%
df.iloc[215].raw_file_path
# Out:
# 'C:/Users/samue/git/figma-rag/data/raw/figma_docs/help_center/help-center-26620239826199-layers-101-explore-layer-types.html'
